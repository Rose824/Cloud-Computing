# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/mschermann/forensic_accounting/master/fb_sub.csv')

# %%
data.head()
# Out:
#                    adsh      cik          name     sic countryba stprba  \
# 0  0001326801-14-000032  1326801  FACEBOOK INC  7370.0        US     CA
# 1  0001326801-14-000068  1326801  FACEBOOK INC  7370.0        US     CA
# 2  0001326801-18-000009  1326801  FACEBOOK INC  7370.0        US     CA
# 3  0001326801-16-000043  1326801  FACEBOOK INC  7370.0        US     CA
# 4  0001326801-14-000023  1326801  FACEBOOK INC  7370.0        US     CA
#
#        cityba  zipba              bas1  bas2  ...  fp     filed  \
# 0  MENLO PARK  94025  1601 WILLOW ROAD   NaN  ...  Q2  20140724
# 1  MENLO PARK  94025  1601 WILLOW ROAD   NaN  ...  Q3  20141030
# 2  MENLO PARK  94025  1601 WILLOW ROAD   NaN  ...  FY  20180201
# 3  MENLO PARK  94025  1601 WILLOW ROAD   NaN  ...  FY  20160128
# 4  MENLO PARK  94025  1601 WILLOW ROAD   NaN  ...  Q1  20140425
#
#                 accepted prevrpt  detail         instance  nciks aciks  \
# 0  2014-07-24 16:26:00.0       0       1  fb-20140630.xml      1   NaN
# ...

# %%
data.name.unique()
# Out:
# array(['FACEBOOK INC'], dtype=object)
